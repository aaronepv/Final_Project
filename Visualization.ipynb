# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (8, 6)

# %%
df1 = pd.read_csv('data/final_dataset.csv')

# %%
df2 = pd.read_csv('data/mens_fighters.csv')

# %%
df3 = pd.read_csv('data/women_fighters.csv')

# %%
df1.head()
# Out:
#            R_fighter       B_fighter          Referee        date  \
# 0       Henry Cejudo   Marlon Moraes     Marc Goddard  2019-06-08
# 1      Tony Ferguson  Donald Cerrone  Dan Miragliotta  2019-06-08
# 2      Jimmie Rivera        Petr Yan  Kevin MacDonald  2019-06-08
# 3        Tai Tuivasa   Blagoy Ivanov  Dan Miragliotta  2019-06-08
# 4  Aljamain Sterling    Pedro Munhoz     Marc Goddard  2019-06-08
#
#                  location Winner  title_bout  weight_class  no_of_rounds  \
# 0  Chicago, Illinois, USA    Red        True  Bantamweight             5
# 1  Chicago, Illinois, USA    Red       False   Lightweight             3
# 2  Chicago, Illinois, USA   Blue       False  Bantamweight             3
# 3  Chicago, Illinois, USA   Blue       False   Heavyweight             3
# 4  Chicago, Illinois, USA    Red       False  Bantamweight             3
#
#    B_current_lose_streak  ...  R_wins  R_Stance  R_Height_cms  R_Reach_cms  \
# ...

# %%
df2.head()
# Out:
#            R_fighter       B_fighter          Referee        date  \
# 0       Henry Cejudo   Marlon Moraes     Marc Goddard  2019-06-08
# 1      Tony Ferguson  Donald Cerrone  Dan Miragliotta  2019-06-08
# 2      Jimmie Rivera        Petr Yan  Kevin MacDonald  2019-06-08
# 3        Tai Tuivasa   Blagoy Ivanov  Dan Miragliotta  2019-06-08
# 4  Aljamain Sterling    Pedro Munhoz     Marc Goddard  2019-06-08
#
#                  location Winner  title_bout  weight_class  no_of_rounds  \
# 0  Chicago, Illinois, USA    Red        True  Bantamweight             5
# 1  Chicago, Illinois, USA    Red       False   Lightweight             3
# 2  Chicago, Illinois, USA   Blue       False  Bantamweight             3
# 3  Chicago, Illinois, USA   Blue       False   Heavyweight             3
# 4  Chicago, Illinois, USA    Red       False  Bantamweight             3
#
#    B_current_lose_streak  ...  R_wins  R_Stance  R_Height_cms  R_Reach_cms  \
# ...

# %%
df3.head()
# Out:
#                R_fighter          B_fighter          Referee        date  \
# 0   Valentina Shevchenko        Jessica Eye  Robert Madrigal  2019-06-08
# 1         Tatiana Suarez      Nina Ansaroff  Robert Madrigal  2019-06-08
# 2  Karolina Kowalkiewicz       Alexa Grasso  Kevin MacDonald  2019-06-08
# 3            Yan Xiaonan        Angela Hill  Robert Madrigal  2019-06-08
# 4      Katlyn Chookagian  Joanne Calderwood  Dan Miragliotta  2019-06-08
#
#                  location Winner  title_bout         weight_class  \
# 0  Chicago, Illinois, USA    Red        True    Women's Flyweight
# 1  Chicago, Illinois, USA    Red       False  Women's Strawweight
# 2  Chicago, Illinois, USA   Blue       False  Women's Strawweight
# 3  Chicago, Illinois, USA    Red       False  Women's Strawweight
# 4  Chicago, Illinois, USA    Red       False    Women's Flyweight
#
#    no_of_rounds  B_current_lose_streak  ...  R_wins  R_Stance  R_Height_cms  \
# ...

# %% [markdown]
# ## We could observe that the age of the fighters is concentrated between 25 and 30 years old (Men Fighters)

# %%
f,ax=plt.subplots(1,2,figsize=(10,8))
sns.distplot(df2['R_age'], ax=ax[0])

ax[0].set_title('R_age')
ax[0].set_ylabel('')
hist = sns.distplot(df2['B_age'],ax=ax[1])

ax[1].set_title('B_age')
plt.show();

# %% [markdown]
# ## Most of the winners are between 28 and 30 years old (Men Fighters)

# %%
f,ax=plt.subplots(1,2,figsize=(10,8))
df2[df2['Winner']=='Red']['R_age'].value_counts().plot.bar(ax=ax[0])

ax[0].set_title('R_age')
ax[0].set_ylabel('')
bar = df2[df2['Winner']=='Blue']['B_age'].value_counts().plot.bar(ax=ax[1])

ax[1].set_title('B_age')
plt.show();

# %% [markdown]
# ## We could observe that the main location for the fight even are in USA

# %%
df2['country'] = df2['location'].apply(lambda x : x.split(',')[-1])

# %%
df2.country.value_counts().sort_values(ascending=True).plot(kind="barh");

# %% [markdown]
# ## The most common class weight is Lightweight and  Welterweight (Men Fighters)

# %%
plt.figure(figsize=(15,8))
values = df2['weight_class'].value_counts()
labels = values.index
sns.barplot(x=values,y=labels)
plt.title('UFC Weight Class')
plt.show()

# %% [markdown]
# ## The most popular stance in the winners is orthodox (Men Fighters)

# %%
f,ax=plt.subplots(1,2,figsize=(10,8))
df2[df2['Winner']=='Red']['R_Stance'].value_counts().plot.bar(ax=ax[0])

ax[0].set_title('R_Stance')
ax[0].set_ylabel('')
bar = df2[df2['Winner']=='Blue']['B_Stance'].value_counts().plot.bar(ax=ax[1])

ax[1].set_title('B_Stance')
plt.show();

# %% [markdown]
# ## The most common class weight is Strawweight and  Bantamweight (Women Fighters)

# %%
plt.figure(figsize=(15,8))
values = df3['weight_class'].value_counts()
labels = values.index
sns.barplot(x=values,y=labels)
plt.title('UFC Weight Class')
plt.show()

# %% [markdown]
# ### We could observe that the age of the fighters is concentrated between 26 and 32 years old (Women Fighters)

# %%
f,ax=plt.subplots(1,2,figsize=(10,8))
sns.distplot(df3['R_age'], ax=ax[0])

ax[0].set_title('R_age')
ax[0].set_ylabel('')
hist = sns.distplot(df3['B_age'],ax=ax[1])

ax[1].set_title('B_age')
plt.show();

# %% [markdown]
# ## The most popular stance in the winners is orthodox (Women Fighters)

# %%
f,ax=plt.subplots(1,2,figsize=(10,8))
df3[df3['Winner']=='Red']['R_Stance'].value_counts().plot.bar(ax=ax[0])

ax[0].set_title('R_Stance')
ax[0].set_ylabel('')
bar = df3[df3['Winner']=='Blue']['B_Stance'].value_counts().plot.bar(ax=ax[1])

ax[1].set_title('B_Stance')
plt.show();

# %% [markdown]
# ## Most of the winners are between 28 and 30 years old (Women Fighters)

# %%
f,ax=plt.subplots(1,2,figsize=(10,8))
df3[df3['Winner']=='Red']['R_age'].value_counts().plot.bar(ax=ax[0])

ax[0].set_title('R_age')
ax[0].set_ylabel('')
bar = df3[df3['Winner']=='Blue']['B_age'].value_counts().plot.bar(ax=ax[1])

ax[1].set_title('B_age')
plt.show();

# %%
df1["gender_bi"]= [0 if value == "M" else 1 for value in df1["gender"]] # 0=Male  , 1=Female

# %%
gender_=df1.gender.value_counts()

# %% [markdown]
# ## This will show the disproportion of the quantity of male combats with the female combats

# %%
fig, ax = plt.subplots(1, figsize=(8,6))
plt.style.use('seaborn')

gender_.plot(kind="bar")
plt.xlabel('Gender')
plt.ylabel('Quantity')
plt.title('Quantity of Male and Female')
ticks = ["Male (4830)","Female (314)"]
ax.set_xticklabels(ticks)

plt.show()

# %% [markdown]
# ## Distribution of the winners (Red and Blue) by weight class

# %%
f,ax=plt.subplots(1,2,figsize=(10,8))
df1[df1['Winner']=='Red']['weight_class'].value_counts().plot.bar(ax=ax[0])

ax[0].set_title('Red Winner')
ax[0].set_ylabel('')
bar = df1[df1['Winner']=='Blue']['weight_class'].value_counts().plot.bar(ax=ax[1])

ax[1].set_title('Blue Winner')
plt.show();

# %%
df1.head()
# Out:
#            R_fighter       B_fighter          Referee        date  \
# 0       Henry Cejudo   Marlon Moraes     Marc Goddard  2019-06-08
# 1      Tony Ferguson  Donald Cerrone  Dan Miragliotta  2019-06-08
# 2      Jimmie Rivera        Petr Yan  Kevin MacDonald  2019-06-08
# 3        Tai Tuivasa   Blagoy Ivanov  Dan Miragliotta  2019-06-08
# 4  Aljamain Sterling    Pedro Munhoz     Marc Goddard  2019-06-08
#
#                  location Winner  title_bout  weight_class  no_of_rounds  \
# 0  Chicago, Illinois, USA    Red        True  Bantamweight             5
# 1  Chicago, Illinois, USA    Red       False   Lightweight             3
# 2  Chicago, Illinois, USA   Blue       False  Bantamweight             3
# 3  Chicago, Illinois, USA   Blue       False   Heavyweight             3
# 4  Chicago, Illinois, USA    Red       False  Bantamweight             3
#
#    B_current_lose_streak  ...  R_Stance  R_Height_cms  R_Reach_cms  \
# ...

# %%
sns.set(style="whitegrid")

g = sns.countplot(df1["Winner"], hue=df1.weight_class)

# %% [markdown]
# ## We need to take out the open Weight and Catch Weight because they do not let us observe properly the distribution of the fighters by weight

# %%
df2.drop(df2[df2.weight_class == "Open Weight"].index, inplace=True)

# %%
df2.drop(df2[df2.weight_class == "Catch Weight"].index, inplace=True)

# %% [markdown]
# ## We can observe that the heavyweight category are lots of variety in weight and height

# %%
sns.relplot(data=df2, x="R_Weight_lbs", y="R_Height_cms", hue="weight_class");

# %% [markdown]
# ## We could see in the female division that the weight are more controlled than the males

# %%
sns.relplot(data=df3, x="R_Weight_lbs", y="R_Height_cms", hue="weight_class");
